# %% [markdown]
# The dataset file can be downloaded from huggingface: https://huggingface.co/lingxusb/TXpredict/resolve/main/TXpredictDB_v1.csv?download=true

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# ------------------------------------------------
# 1. Read the CSV containing Folder, Filename, Length
# ------------------------------------------------
csv_path = 'C:/Work/CellState/20250121_TXpredictDB/TXpredictDB_v1.csv'  # Change to your CSV file
df = pd.read_csv(csv_path)
df
# Out:
#                          genome_name
# 0        GCA_001975265.1_ASM197526v1  \
# 1        GCA_001975265.1_ASM197526v1
# 2        GCA_001975265.1_ASM197526v1
# 3        GCA_001975265.1_ASM197526v1
# 4        GCA_001975265.1_ASM197526v1
# ...                              ...
# 9865972    GCA_900235035.2_KP_7435-4
# 9865973    GCA_900235035.2_KP_7435-4
# 9865974    GCA_900235035.2_KP_7435-4
# 9865975    GCA_900235035.2_KP_7435-4
# 9865976    GCA_900235035.2_KP_7435-4
#
#                                                  locus_tag
# 0                                               LFZ2_00010  \
# 1                                               LFZ2_00015
# 2                                               LFZ2_00020
# 3                                               LFZ2_00025
# 4                                               LFZ2_00030
# ...                                                    ...
# 9865972                                     BQ9382_C4-5328
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns_palette = sns.color_palette("tab10")

map_taxa_to_color = {
    'bacteria': sns_palette[0],
    'archaea':  sns_palette[1],
    'fungi':    sns_palette[2]
}

taxa_colors = df['taxa'].map(map_taxa_to_color)

fig, ax = plt.subplots(figsize=(5.5, 5.5), dpi=600, layout='constrained')
scatter = ax.scatter(
    df['x'].values,
    df['y'].values,
    s=0.2,
    c=taxa_colors,
    marker='.',
    linewidths=None,
    ec='None',
    alpha=0.8,
    rasterized=True
)

ax.axis('equal')
ax.grid(False)
ax.set_xticks([])
ax.set_yticks([])
ax.axis('off')

# ------------------------------------------------
# 7. Save and show
# ------------------------------------------------
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 12
#       4 sns_palette = sns.color_palette("tab10")
#       6 map_taxa_to_color = {
#       7     'bacteria': sns_palette[0],
#       8     'archaea':  sns_palette[1],
#       9     'fungi':    sns_palette[2]
#      10 }
# ---> 12 taxa_colors = df_all['taxa'].map(map_taxa_to_color)
#      14 fig, ax = plt.subplots(figsize=(5.5, 5.5), dpi=600, layout='constrained')
#      15 scatter = ax.scatter(
#      16     df_all['x'].values,
#      17     df_all['y'].values,
#    (...)
#      24     rasterized=True
#      25 )
#
# NameError: name 'df_all' is not defined
